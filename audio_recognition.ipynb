# %% [markdown]
# # 오디오 클래스 분류
#
# - C:\Users\사용자이름에서 "pannds_data" 폴더 생성 후 거기에 pth 파일 및 label.csv을 위치시켜야함.

# %%
import utils

audio_url = "https://www.youtube.com/watch?v=2SATljljXCY"
audio, sr = utils.getAudioCroppedFromURL(audio_url)

clipwise_output = utils.audioTagging('cuda', audio, 5)
# Out:
# Checkpoint path: C:\Users\KHU/panns_data/Cnn14_mAP=0.431.pth
# GPU number: 1
# Music                          : 0.572
# Speech                         : 0.313
# Vehicle                        : 0.071
# Musical instrument             : 0.054
# Outside, urban or manmade      : 0.053

# %%
utils.eventDetectionWithPerTopk('cuda', audio, 0.2)
# Out:
# Checkpoint path: C:\Users\KHU/panns_data/Cnn14_DecisionLevelMax.pth
# GPU number: 1
#
# 최대 확률이 0.2 이상인 클래스 수: 3개
# - Music: 최대 0.641
# - Speech: 최대 0.517
# - Vehicle: 최대 0.295
