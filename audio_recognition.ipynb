# %% [markdown]
# # 오디오 클래스 분류
#
# - C:\Users\사용자이름에서 "pannds_data" 폴더 생성 후 거기에 pth 파일 및 label.csv을 위치시켜야함.

# %%
import utils

audio_url = "https://www.youtube.com/watch?v=CklwuE4DJxY"
audio, sr = utils.getAudioCroppedFromURL(audio_url)

clipwise_output = utils.audioTagging('cuda', audio, 5)
# Out:
# Checkpoint path: C:\Users\KHU/panns_data/Cnn14_mAP=0.431.pth
# GPU number: 1
# Speech                         : 0.873
# Music                          : 0.858
# Shatter                        : 0.201
# Inside, large room or hall     : 0.084
# Thunk                          : 0.084

# %%
audio.shape
# Out:
# (1, 9024204)

# %%
utils.eventDetectionWithPerTopk('cuda', audio, 0.3)
# Out:
# Checkpoint path: C:\Users\KHU/panns_data/Cnn14_DecisionLevelMax.pth
# GPU number: 1
#
# 최대 확률이 0.3 이상인 클래스 수: 5개
# - Zipper (clothing): 최대 0.896
# - Speech: 최대 0.689
# - Music: 최대 0.638
# - Shatter: 최대 0.592
# - Percussion: 최대 0.312
